# %% [markdown]
# ### Example 4
# - https://jakevdp.github.io/PythonDataScienceHandbook/03.11-working-with-time-series.html

# %% [markdown]
# #### Import Libraries

# %%
from datetime import datetime  #Native Python dates and times
from dateutil import parser
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %matplotlib inline

from pandas.tseries.offsets import BDay

#A related package to be aware of is pytz
import pytz  # Not explored

# %%
#Set Fig Size
def reset_figsize():
    plt.rcParams["figure.figsize"] = (15, 6)

# %% [markdown]
# ##### datetime

# %%
## Example -1
datetime(year=2018,month =3, day = 26)
# Out:
# datetime.datetime(2018, 3, 26, 0, 0)

# %% [markdown]
# ##### dateutil parser

# %%
## Example -2
#http://labix.org/python-dateutil

parser.parse('26th of March 2018')
parser.parse('26th March 2018')
parser.parse('26 of March 2018')
parser.parse('26 March 2018')
parser.parse('26 Mar 2018')
parser.parse('March 26 2018')
parser.parse('26-March-2018')
parser.parse('26/03/2018')
parser.parse('03/26/2018')

date = parser.parse('26th of March 2018')
date
# Out:
# datetime.datetime(2018, 3, 26, 0, 0)

# %%
#Printing the day of the week:
#https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

date.strftime('%A')
# Out:
# 'Monday'

# %% [markdown]
# ##### Typed arrays of times: NumPy's datetime64

# %%
date = np.array('2018-03-26', dtype = np.datetime64)
date
# Out:
# array('2018-03-26', dtype='datetime64[D]')

# %%
#https://jakevdp.github.io/PythonDataScienceHandbook/02.03-computation-on-arrays-ufuncs.html
#https://docs.scipy.org/doc/numpy/reference/arrays.datetime.html

date + np.arange(12)
# Out:
# array(['2018-03-26', '2018-03-27', '2018-03-28', '2018-03-29',
#        '2018-03-30', '2018-03-31', '2018-04-01', '2018-04-02',
#        '2018-04-03', '2018-04-04', '2018-04-05', '2018-04-06'],
#       dtype='datetime64[D]')

# %%
np.datetime64('2018-03-26')
np.datetime64('2018-03-26 07:38')
np.datetime64('2018-03-26 07:38', 'ns')
# Out:
# numpy.datetime64('2018-03-26T07:38:00.000000000')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.datetime64('2018-03-26', 'Y')
np.datetime64('2018-03-26', 'M')
np.datetime64('2018-03-26', 'D')
# Out:
# numpy.datetime64('2018-03-26')

# %% [markdown]
# ##### Dates and times in pandas: best of both worlds
# - Pandas builds upon all the tools just discussed to provide a Timestamp object, which combines the ease-of-use of datetime and dateutil with the efficient storage and vectorized interface of numpy.datetime64. From a group of these Timestamp objects, Pandas can construct a DatetimeIndex that can be used to index data in a Series or DataFrame

# %%
date = pd.to_datetime('26th march 2018')
date
# Out:
# Timestamp('2018-03-26 00:00:00')

# %%
date.strftime('%A')
# Out:
# 'Monday'

# %%
date + pd.to_timedelta(np.arange(12), 'D')
# Out:
# DatetimeIndex(['2018-03-26', '2018-03-27', '2018-03-28', '2018-03-29',
#                '2018-03-30', '2018-03-31', '2018-04-01', '2018-04-02',
#                '2018-04-03', '2018-04-04', '2018-04-05', '2018-04-06'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ##### Pandas Time Series: Indexing by Time

# %%
indx = pd.DatetimeIndex(pd.to_datetime('26th march 2018') + pd.to_timedelta(np.arange(4), 'D'))
indx

data = pd.Series([0,1,2,3], index = indx)
data
# Out:
# 2018-03-26    0
# 2018-03-27    1
# 2018-03-28    2
# 2018-03-29    3
# dtype: int64

# %%
data['2018-03-26':'2018-03-28']
# Out:
# 2018-03-26    0
# 2018-03-27    1
# 2018-03-28    2
# dtype: int64

# %%
data['2018']
# Out:
# 2018-03-26    0
# 2018-03-27    1
# 2018-03-28    2
# 2018-03-29    3
# dtype: int64

# %%
dates = pd.to_datetime([datetime(2015, 7, 3), '4th of July, 2015',
                       '2015-Jul-6', '07-07-2015', '20150708'])
dates
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#                '2015-07-08'],
#               dtype='datetime64[ns]', freq=None)

# %%
dates.to_period('D')
# Out:
# PeriodIndex(['2015-07-03', '2015-07-04', '2015-07-06', '2015-07-07',
#              '2015-07-08'],
#             dtype='period[D]', freq='D')

# %%
dates - dates[0]
# Out:
# TimedeltaIndex(['0 days', '1 days', '3 days', '4 days', '5 days'], dtype='timedelta64[ns]', freq=None)

# %% [markdown]
# ##### Regular sequences:

# %%
pd.date_range('2015-07-03', '2015-07-10')
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8)
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range('2015-07-03', periods=8, freq='H')
# Out:
# DatetimeIndex(['2015-07-03 00:00:00', '2015-07-03 01:00:00',
#                '2015-07-03 02:00:00', '2015-07-03 03:00:00',
#                '2015-07-03 04:00:00', '2015-07-03 05:00:00',
#                '2015-07-03 06:00:00', '2015-07-03 07:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.period_range('2015-07', periods=8, freq='M')
# Out:
# PeriodIndex(['2015-07', '2015-08', '2015-09', '2015-10', '2015-11', '2015-12',
#              '2016-01', '2016-02'],
#             dtype='period[M]', freq='M')

# %%
pd.timedelta_range(0, periods=10, freq='H')
# Out:
# TimedeltaIndex(['00:00:00', '01:00:00', '02:00:00', '03:00:00', '04:00:00',
#                 '05:00:00', '06:00:00', '07:00:00', '08:00:00', '09:00:00'],
#                dtype='timedelta64[ns]', freq='H')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.timedelta_range(0, periods=9, freq="2H30T")
# Out:
# TimedeltaIndex(['00:00:00', '02:30:00', '05:00:00', '07:30:00', '10:00:00',
#                 '12:30:00', '15:00:00', '17:30:00', '20:00:00'],
#                dtype='timedelta64[ns]', freq='150T')

# %%
pd.date_range('2018-03-23', periods=5, freq=BDay())
# Out:
# DatetimeIndex(['2018-03-23', '2018-03-26', '2018-03-27', '2018-03-28',
#                '2018-03-29'],
#               dtype='datetime64[ns]', freq='B')

# %% [markdown]
# ##### Resampling, Shifting, and Windowing

# %%
goog = pd.read_csv('../Datasets/HDFCBANK.csv')
goog.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-03-26  606.000000  617.500000  602.549988  614.500000  590.980469
# 1  2013-03-28  614.500000  631.150024  606.950012  625.349976  601.415100
# 2  2013-04-01  625.349976  629.000000  621.000000  623.849976  599.972534
# 3  2013-04-02  625.000000  634.299988  617.900024  629.900024  605.790955
# 4  2013-04-03  628.000000  631.650024  619.500000  623.650024  599.780273
#
#       Volume
# 0  3318601.0
# 1  4874023.0
# 2  1677193.0
# 3  1714355.0
# 4  1675904.0

# %%
#set Index
print(len(goog))
goog['Date'] = pd.to_datetime(goog['Date'])
print(goog.head(2))

goog.set_index('Date', inplace=True)
print(goog.head(2))
# Out:
# 1231
#         Date   Open        High         Low       Close   Adj Close     Volume
# 0 2013-03-26  606.0  617.500000  602.549988  614.500000  590.980469  3318601.0
# 1 2013-03-28  614.5  631.150024  606.950012  625.349976  601.415100  4874023.0
#              Open        High         Low       Close   Adj Close     Volume
# Date
# 2013-03-26  606.0  617.500000  602.549988  614.500000  590.980469  3318601.0
# 2013-03-28  614.5  631.150024  606.950012  625.349976  601.415100  4874023.0

# %%
goog = goog['Close']
goog.head(2)
# Out:
# Date
# 2013-03-26    614.500000
# 2013-03-28    625.349976
# Name: Close, dtype: float64

# %%
reset_figsize()

goog.plot()
plt.show()

# %%
goog.plot(alpha=0.5, style='-')
goog.resample('BA').mean().plot(style=':')
goog.asfreq('BA').plot(style='--');
plt.legend(['input', 'resample', 'asfreq'],
           loc='upper left');

# %%
fig, ax = plt.subplots(2, sharex=True)
data = goog.iloc[:10]

data.asfreq('D').plot(ax=ax[0], marker='o')

data.asfreq('D', method='bfill').plot(ax=ax[1], style='-o')
data.asfreq('D', method='ffill').plot(ax=ax[1], style='--o')
ax[1].legend(["back-fill", "forward-fill"]);

# %% [markdown]
# ##### Time-shifts
#
# Another common time series-specific operation is shifting of data in time. Pandas has two closely related methods for computing this: shift() and tshift() In short, the difference between them is that shift() shifts the data, while tshift() shifts the index. In both cases, the shift is specified in multiples of the frequency.

# %%
fig, ax = plt.subplots(3, sharey=True)

# # apply a frequency to the data
goog = goog.asfreq('D', method='pad')

goog.plot(ax=ax[0])
goog.shift(400).plot(ax=ax[1])
goog.tshift(400).plot(ax=ax[2])

# # legends and annotations
local_max = pd.to_datetime('2015-12-13')
offset = pd.Timedelta(400, 'D')

ax[0].legend(['input'], loc=2)
ax[0].get_xticklabels()[2].set(weight='heavy', color='red')
ax[0].axvline(local_max, alpha=0.3, color='red')

ax[1].legend(['shift(400)'], loc=2)
ax[1].get_xticklabels()[2].set(weight='heavy', color='red')
ax[1].axvline(local_max + offset, alpha=0.3, color='red')

ax[2].legend(['tshift(400)'], loc=2)
ax[2].get_xticklabels()[1].set(weight='heavy', color='red')
ax[2].axvline(local_max + offset, alpha=0.3, color='red');

# %%
ROI = 100 * (goog.tshift(-365) / goog - 1)
ROI.plot()
plt.ylabel('% Return on Investment');

# %% [markdown]
# #### Rolling windows

# %%
rolling = goog.rolling(365, center=True)

data = pd.DataFrame({'input': goog,
                     'one-year rolling_mean': rolling.mean(),
                     'one-year rolling_std': rolling.std()})
ax = data.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha(0.3)

# %% [markdown]
# #### Example: Visualizing Seattle Bicycle Counts

# %%
#https://data.seattle.gov/api/views/65db-xm6k/rows.csv?accessType=DOWNLOAD
data = pd.read_csv('../Datasets/FremontBridge.csv', index_col='Date', parse_dates=True)
data.head()
# Out:
#                      Fremont Bridge West Sidewalk  \
# Date
# 2012-10-03 00:00:00                           4.0
# 2012-10-03 01:00:00                           4.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           2.0
# 2012-10-03 04:00:00                           6.0
#
#                      Fremont Bridge East Sidewalk
# Date
# 2012-10-03 00:00:00                           9.0
# 2012-10-03 01:00:00                           6.0
# 2012-10-03 02:00:00                           1.0
# 2012-10-03 03:00:00                           3.0
# 2012-10-03 04:00:00                           1.0

# %%
data.columns = ['West', 'East']
data['Total'] = data.eval('West + East')
data.dropna().describe()
# Out:
#                West         East         Total
# count  47392.000000  47392.00000  47392.000000
# mean      54.750739     54.95801    109.708748
# std       73.259235     79.62978    138.790226
# min        0.000000      0.00000      0.000000
# 25%        7.000000      7.00000     15.000000
# 50%       29.000000     28.00000     59.000000
# 75%       72.000000     67.00000    143.000000
# max      854.000000    717.00000   1165.000000

# %%
data.plot()
plt.ylabel('Hourly Bicycle Count');

# %%
weekly = data.resample('W').sum()
weekly.plot(style=[':', '--', '-'])
plt.ylabel('Weekly bicycle count');

# %%
daily = data.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=[':', '--', '-'])
plt.ylabel('mean hourly count');

# %%
daily.rolling(50, center=True,
              win_type='gaussian').sum(std=10).plot(style=[':', '--', '-']);

# %%
by_time = data.groupby(data.index.time).mean()
hourly_ticks = 4 * 60 * 60 * np.arange(6)
by_time.plot(xticks=hourly_ticks, style=[':', '--', '-']);

# %%
by_weekday = data.groupby(data.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=[':', '--', '-']);

# %%
weekend = np.where(data.index.weekday < 5, 'Weekday', 'Weekend')
by_time = data.groupby([weekend, data.index.time]).mean()

# %%
fig, ax = plt.subplots(1, 2, figsize=(14, 5))
by_time.loc['Weekday'].plot(ax=ax[0], title='Weekdays',
                           xticks=hourly_ticks, style=[':', '--', '-'])
by_time.loc['Weekend'].plot(ax=ax[1], title='Weekends',
                           xticks=hourly_ticks, style=[':', '--', '-']);
